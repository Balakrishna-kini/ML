# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing #fetching dataset from library

# %%
df = pd.read_csv('california_housing.csv')

# %%
correlation_matrix=df.corr()
print('Correlation Matrix:\n',correlation_matrix)
# Out:
# Correlation Matrix:
#                      longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.052751           -0.046145     0.331258
# latitude            -0.052751  1.000000            0.060447     0.189709
# housing_median_age  -0.046145  0.060447            1.000000    -0.138924
# total_rooms          0.331258  0.189709           -0.138924     1.000000
# total_bedrooms       0.108666  0.007117           -0.227759     0.867630
# population           0.181194 -0.065513           -0.147745     0.871670
# households           0.136627  0.028790           -0.226771     0.879455
# median_income        0.726963  0.312555           -0.047892     0.315918
# median_house_value   0.679471  0.324280           -0.072749     0.392827
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.108666    0.181194    0.136627       0.726963
# latitude                  0.007117   -0.065513    0.028790       0.312555
# housing_median_age       -0.227759   -0.147745   -0.226771      -0.047892
# total_rooms               0.867630    0.871670    0.879455       0.315918
# total_bedrooms            1.000000    0.907093    0.996114      -0.013819
# population                0.907093    1.000000    0.905528       0.011754
# households                0.996114    0.905528    1.000000       0.017217
# median_income            -0.013819    0.011754    0.017217       1.000000
# median_house_value        0.141237    0.086476    0.172206       0.799649
#
#                     median_house_value
# longitude                     0.679471
# latitude                      0.324280
# housing_median_age           -0.072749
# total_rooms                   0.392827
# total_bedrooms                0.141237
# population                    0.086476
# households                    0.172206
# median_income                 0.799649
# median_house_value            1.000000

# %%
plt.figure(figsize=(12,8))
heatmap=sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',linewidths=0.25)
plt.title('Correlation Matrix heatmap')
plt.show()

# %%
sns.pairplot(df)
plt.suptitle('Pair plot of California Housing Dataset',y=1.02)
plt.show()
